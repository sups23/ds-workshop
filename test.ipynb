# %%
print("Hello world!")
# Out:
# Hello world!

# %%
for i in range(1,10):
    print("Hello world!")
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);  # Plot some data on the axes.

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.

# %%
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);  # Plot some data on the axes.

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);  # Plot some data on the axes.

# %%
ax.plot([1, 2, 3, 4], [5, 6, 7, 8]);

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4], [5,6,7,8])

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4], [1,6,3,8])
